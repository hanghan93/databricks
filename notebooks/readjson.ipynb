# %% [markdown]
# Here I've mounted the Azure Data Lake Gen1 to Databricks, to mount the ADLS we need Application Id(Client Id), Directory Id(Tenant Id) and Access Key.
# To register the databricks application in the Azure Active Directory, Go through the official documentation of Azure Databricks for application registration.
# AccessKey is a confidential information and not expose with others, so I've stored it in the Secrets

# %%
configs = {"fs.adl.oauth2.access.token.provider.type": "ClientCredential",
          "fs.adl.oauth2.client.id": "b14bc278-a035-40a8-926d-b9a4956ec4fe",
          "fs.adl.oauth2.credential": dbutils.secrets.get(scope = "datalake", key = "accessKey"),
          "fs.adl.oauth2.refresh.url": "https://login.microsoftonline.com/908e362c-4c43-4b9b-891e-7d4a98b920d5/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1107048650925840&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      8</span>   source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;adl://dlshardikpocsdev.azuredatalakestore.net/&#34;</span><span class="ansi-blue-fg">,</span>
# ...

# %% [markdown]
# To avoid getting the below error, it is wise to check the mount is already there before mounting again or start doing any operation without mountpoint
#
# ava.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/datalake; nested exception is:

# %%
def mountIfNot(str_path):
    if any(mount.mountPoint == str_path for mount in dbutils.fs.mounts()):
      print(str_path, ' path is already mounted')
    else:
      dbutils.fs.mount(source = "adl://dlshardikpocsdev.azuredatalakestore.net/",mount_point = "/mnt/datalake", extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mountIfNot('/mnt/datalake')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/datalake  path is already mounted
# </div>

# %% [markdown]
# Check the list of files available in the mounted path

# %%
dbutils.fs.ls("dbfs:/mnt/datalake/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/mnt/datalake/delta/&#39;, name=&#39;delta/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/datalake/hotel/&#39;, name=&#39;hotel/&#39;, size=0)]</div>

# %% [markdown]
# Now we can read all the files available in a data lake same like a local files, let's create a spark data frame from the csv file

# %%
df = spark.read.csv("/mnt/datalake/hotel/listings.csv", sep = "," ,inferSchema=True, header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
##Write out DataFrame as Databricks Delta data
df.write.format("delta").mode("overwrite").partitionBy("country").save("/mnt/datalake/delta/listing/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-162815669543000&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg">##Write out DataFrame as Databricks Delta data</span>
# ...

# %%
##Create delta table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.sql("DROP TABLE IF EXISTS listings"))

display(spark.sql("CREATE TABLE listings USING DELTA LOCATION '/mnt/datalake/delta/listing/'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM listings LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
